# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
a = pd.read_csv ('survey2.csv')

# %%
a.head()
# Out:
#    response   Q1       Q2      Q3        Q4             Q5  \
# 0         1  yes  18 - 29  female  computer  don't like it
# 1         2  yes  30 - 39    male  computer        like it
# 2         3  yes  18 - 29    male  computer        neutral
# 3         4  yes  18 - 29  female  computer  don't like it
# 4         5  yes  18 - 29    male  computer        like it
#
#                                                   Q6   Q7  \
# 0  I have a video based online system at work whi...  yes
# 1                                                NaN  yes
# 2                                                NaN  yes
# 3  I'm a little confused as to what I need to do....  yes
# 4                                     Good interface  yes
#
#                               Q8             Q9                    Q10  \
# 0     new interface listed above  don't like it  extremely unnecessary
# 1     new interface listed above        like it              necessary
# 2     new interface listed above        neutral                neutral
# 3  the original piazza interface        neutral            unnecessary
# 4     new interface listed above        like it            unnecessary
#
#              Q11  Q12            Q13                         Q14
# 0  don't like it  yes  don't like it                         NaN
# 1        like it  yes        like it                         NaN
# 2        neutral  yes        like it                         NaN
# 3        like it  yes        like it                         NaN
# 4        neutral  yes        like it  I really like this version

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 15 columns):
# response    19 non-null int64
# Q1          19 non-null object
# Q2          19 non-null object
# Q3          19 non-null object
# Q4          19 non-null object
# Q5          19 non-null object
# Q6          15 non-null object
# Q7          19 non-null object
# Q8          19 non-null object
# Q9          19 non-null object
# Q10         19 non-null object
# Q11         19 non-null object
# Q12         19 non-null object
# Q13         19 non-null object
# Q14         6 non-null object
# dtypes: int64(1), object(14)
# memory usage: 2.3+ KB

# %%
b=a['Q1'].value_counts()
b=b/sum(b)
b
c = plt.pie(b, labels=b.index,autopct='%1.1f%%');
plt.title('Have you used canvas quizzes before?')
plt.show()

# %%
b=a['Q2'].value_counts()
b=b/sum(b)
b
c = plt.pie(b, labels=b.index,autopct='%1.1f%%');
plt.title('What is your age?')
plt.show()

# %%
b=a['Q3'].value_counts()
b=b/sum(b)
b
c = plt.pie(b, labels=b.index,autopct='%1.1f%%');
plt.title('What is your gender?')
plt.show()

# %%
b=a['Q4'].value_counts()
b=b/sum(b)
b
c = plt.pie(b, labels=b.index,autopct='%1.1f%%');
plt.title('Which device did you use to take online exams?')
plt.show()

# %%
b=a['Q5'].value_counts()
b=b/sum(b)
b
c = plt.pie(b, labels=b.index,autopct='%1.1f%%');
plt.title('Do you like to take the quizzes or exams using the interface shown above?')
plt.show()

# %%
b=a['Q7'].value_counts()
b=b/sum(b)
b
c = plt.pie(b, labels=b.index,autopct='%1.1f%%');
plt.title('Can you deleted one of your recorded videos in this interface')
plt.show()

# %%
b=a['Q8'].value_counts()
b=b/sum(b)
b
c = plt.pie(b, labels=b.index,autopct='%1.1f%%');
plt.title('Do you prefer this new interface for online quiz or you prefer the original piazza quizzes?')
plt.show()

# %%
b=a['Q9'].value_counts()
b=b/sum(b)
b
c = plt.pie(b, labels=b.index,autopct='%1.1f%%');
plt.title('How do you think about the note-taking function in this exam?')
plt.show()

# %%
b=a['Q10'].value_counts()
b=b/sum(b)
b
c = plt.pie(b, labels=b.index,autopct='%1.1f%%');
plt.title('Do you think video/voice notes are necessary for this system?')
plt.show()

# %%
b=a['Q11'].value_counts()
b=b/sum(b)
b
c = plt.pie(b, labels=b.index,autopct='%1.1f%%');
plt.title('Do you like the progress bar and the marks (pin, happy face, unhappy face, voice, notes) on this problem?')
plt.show()

# %%
b=a['Q12'].value_counts()
b=b/sum(b)
b
c = plt.pie(b, labels=b.index,autopct='%1.1f%%');
plt.title('Can you find the button to use a built-in calculator and run some codes in 3 seconds?')
plt.show()

# %%
b=a['Q13'].value_counts()
b=b/sum(b)
b
c = plt.pie(b, labels=b.index,autopct='%1.1f%%');
plt.title('Do you like this grades reporting interface?')
plt.show()
