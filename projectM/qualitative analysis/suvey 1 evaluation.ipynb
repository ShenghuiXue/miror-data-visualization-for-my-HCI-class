# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
a = pd.read_csv ('survey1.csv')

# %%
a.head()
# Out:
#    response   Q1       Q2      Q3        Q4                 Q5  \
# 0         1  yes  30 - 39    male  computer            like it
# 1         2  yes  18 - 29  Female  computer            neutral
# 2         3  yes  18 - 29  Female  computer            like it
# 3         4  yes  18 - 29    male  computer            like it
# 4         5  yes  30 - 39    male  computer  extremely like it
#
#                                                   Q6   Q7              Q8  \
# 0          the bookmarks are nice, good progress bar  yes  this interface
# 1  i like the tool tip that the answer is saved. ...  yes  this interface
# 2           LIke the rating system and notes section   no  this interface
# 3  Shows me a view of all the questions, the on-s...  yes  this interface
# 4                                                 na  yes  this interface
#
#         Q9            Q10                Q11  Q12                Q13  \
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 15 columns):
# response    19 non-null int64
# Q1          19 non-null object
# Q2          19 non-null object
# Q3          19 non-null object
# Q4          19 non-null object
# Q5          19 non-null object
# Q6          19 non-null object
# Q7          19 non-null object
# Q8          19 non-null object
# Q9          19 non-null object
# Q10         19 non-null object
# Q11         19 non-null object
# Q12         19 non-null object
# Q13         19 non-null object
# Q14         6 non-null object
# dtypes: int64(1), object(14)
# memory usage: 2.3+ KB

# %%
b=a['Q1'].value_counts()
b=b/sum(b)
b
c = plt.pie(b, labels=b.index,autopct='%1.1f%%');
plt.title('Have you used canvas quizzes before?')
plt.show()

# %%
b=a['Q2'].value_counts()
b=b/sum(b)
b
c = plt.pie(b, labels=b.index,autopct='%1.1f%%');
plt.title('What is your age?')
plt.show()

# %%
b=a['Q3'].value_counts()
b=b/sum(b)
b
c = plt.pie(b, labels=b.index,autopct='%1.1f%%');
plt.title('What is your gender?')
plt.show()

# %%
b=a['Q4'].value_counts()
b=b/sum(b)
b
c = plt.pie(b, labels=b.index,autopct='%1.1f%%');
plt.title('Which device did you use to take online exams?')
plt.show()

# %%
b=a['Q5'].value_counts()
b=b/sum(b)
b
c = plt.pie(b, labels=b.index,autopct='%1.1f%%');
plt.title('Do you like to take the quizzes or exams using the interface shown above?')
plt.show()

# %%
b=a['Q7'].value_counts()
b=b/sum(b)
b
c = plt.pie(b, labels=b.index,autopct='%1.1f%%');
plt.title('When you want some assistance to solve technical problems, you can identify the button to click from the above image?')
plt.show()

# %%
b=a['Q8'].value_counts()
b=b/sum(b)
b
c = plt.pie(b, labels=b.index,autopct='%1.1f%%');
plt.title('Do you prefer this new interface for online quiz or you prefer the original piazza quizzes?')
plt.show()

# %%
b=a['Q9'].value_counts()
b=b/sum(b)
b
c = plt.pie(b, labels=b.index,autopct='%1.1f%%');
plt.title('How do you think about the note-taking function in this exam?')
plt.show()

# %%
b=a['Q10'].value_counts()
b=b/sum(b)
b
c = plt.pie(b, labels=b.index,autopct='%1.1f%%');
plt.title('This interface has four types of book marks. How do you think about these four types of bookmarks in this interface?')
plt.show()

# %%
b=a['Q11'].value_counts()
b=b/sum(b)
b
c = plt.pie(b, labels=b.index,autopct='%1.1f%%');
plt.title('Do you like the progress bar and the marks (pin, happy face, unhappy face, voice, notes) on this problem?')
plt.show()

# %%
b=a['Q12'].value_counts()
b=b/sum(b)
b
c = plt.pie(b, labels=b.index,autopct='%1.1f%%');
plt.title('Can you find the button to use a built-in calculator and run some codes in 3 seconds?')
plt.show()

# %%
b=a['Q13'].value_counts()
b=b/sum(b)
b
c = plt.pie(b, labels=b.index,autopct='%1.1f%%');
plt.title('Do you like this grades reporting interface?')
plt.show()
